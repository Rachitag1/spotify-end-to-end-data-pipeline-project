# %%
# !pip install spotipy
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/spotipy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/spotipy/
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an EnvironmentError: [Errno 28] No space left on device
#   Using cached spotipy-2.23.0-py3-none-any.whl (29 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached urllib3-2.0.7-py3-none-any.whl (124 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11

# %%
 
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-0236b49a3ab0> in <module>
# ----> 1 import spotipy
#       2 from spotipy.oauth2 import SpotifyClientCredentials
#
# ModuleNotFoundError: No module named 'spotipy'

# %%
# !pip install spotipy
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/spotipy/
#   Using cached spotipy-2.23.0-py3-none-any.whl (29 kB)
# ...
#   Using cached redis-5.0.1-py3-none-any.whl (250 kB)
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# ...

# %%
# !pip install spotipy

# %%
import pandas as pd
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#used for authentication that we have permission to get data from spotify
    client_credentials_manager=SpotifyClientCredentials(client_id="d5dbe29435b04f4a8531bf7e093da60b", client_secret="ed9f8b687f4f46cb9f5de3b2905ca451")

# %%
#creating spotify object to extract data from spotify
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
#yeh wo link hai jis playlist ka client analysis karna chahta hai.. 
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
# we are interested in the last element as it is the actual URL.
playlist_link.split('/')
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbMDoHDwVN2tF']

# %%
playlist_URI=playlist_link.split('/')[4]

# %%
# there is a function playlist tracks which pulls all the tracks from the playlist passed.
sp.playlist_tracks(playlist_URI)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-11-04T08:58:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#        'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#        'id': '6HaGTQPmzraVmaVxvz6EUc',
#        'name': 'Jung Kook',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-11-04T08:58:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#        'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#        'id': '6HaGTQPmzraVmaVxvz6EUc',
#        'name': 'Jung Kook',
#        'type': 'artist',
#        'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2023-11-04T08:58:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#       'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#       'id': '6HaGTQPmzraVmaVxvz6EUc',
#       'name': 'Jung Kook',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
#gives 1st album info.
data['items'][0]
# Out:
# {'added_at': '2023-11-04T08:58:25Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#      'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#      'id': '6HaGTQPmzraVmaVxvz6EUc',
#      'name': 'Jung Kook',
#      'type': 'artist',
#      'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#    'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#    'id': '6HaGTQPmzraVmaVxvz6EUc',
#    'name': 'Jung Kook',
#    'type': 'artist',
#    'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5pSk3c3wVwnb2arb6ohCPU'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'GOLDEN'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-11-03'

# %%
data['items'][0]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#   'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#   'id': '6HaGTQPmzraVmaVxvz6EUc',
#   'name': 'Jung Kook',
#   'type': 'artist',
#   'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}]

# %%
data['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'Jung Kook'

# %%
#now, we want to pull the relevant fields for all the albums in items. for this we will use for loop.
album_collated_data = []
id1=[]
name=[]
release_date=[]
totaltracks=[]
for i in data['items']:
    album_id = i['track']['album']['id']
    album_name = i['track']['album']['name']
    album_release_date = i['track']['album']['release_date']
    album_total_tracks = i['track']['album']['total_tracks']
    album_info = {'album_id': album_id, 'name': album_name, 'album_release_date': album_release_date, 'album_total_tracks':album_total_tracks}
    album_collated_data.append(album_info)
    id1.append(album_id)
    name.append(album_name)
    release_date.append(album_release_date)
    totaltracks.append(album_total_tracks)
album_dict = {'album_id':id1,'name':name,'album_release_date':release_date,'album_total_tracks':totaltracks}
print(album_dict)

#print(album_collated_data)
#print(len(album_collated_data))
# Out:
# {'album_id': ['5pSk3c3wVwnb2arb6ohCPU', '5pSk3c3wVwnb2arb6ohCPU', '3UOV8XvCwMKaATRNXrYCjN', '66k6EGkPtYoN44anGIsEPW', '64LU4c1nfjz1t4VnGhagcg', '1bBez9PNvkJPW08bU7NYta', '0fJ0beklzFwoBv01U8792s', '4FftCsAcXXD1nFO9RFUNFO', '1NAmidJlEaVgA3MpcPFYGq', '4FftCsAcXXD1nFO9RFUNFO', '18ogtNq9F7DmMkNYO6Xb4k', '64LU4c1nfjz1t4VnGhagcg', '2Cn1d2KgbkAqbZCJ1RzdkA', '22sXXkKgjEuawIFL1e1tRw', '2qQP2NgOoH6HqknnbpJmIk', '5pSk3c3wVwnb2arb6ohCPU', '64LU4c1nfjz1t4VnGhagcg', '5pSk3c3wVwnb2arb6ohCPU', '0FqAaUEyKCyUNFE1uQPZ7i', '3zu0hJJew2qXZNlselIQk8', '64LU4c1nfjz1t4VnGhagcg', '4x6cjOcVz44aiLSOHCLKPd', '5pSk3c3wVwnb2arb6ohCPU', '5pSk3c3wVwnb2arb6ohCPU', '11UJfH39O0VqLiQGLW0D0e', '3puAvurwvtvi1rodndIPW8', '5pSk3c3wVwnb2arb6ohCPU', '5pSk3c3wVwnb2arb6ohCPU', '5pSk3c3wVwnb2arb6ohCPU', '1bBez9PNvkJPW08bU7NYta', '78bpIziExqiI9qztvNFlQu', '3Fk8yQvPlCHgwR2pNhEIRA', '5MU0RmBSpoSxOPYBfcobDc', '1xJHno7SmdVtZAtXbdbDZp', '4jox3ip1I39DFC2B7R5qLH', '4czdORdCWP9umpbhFXK2fW', '64LU4c1nfjz1t4VnGhagcg', '5cH7FqB7JD5q1tJXJ7FHY
# ...

# %%
data['items'][0]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#   'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#   'id': '6HaGTQPmzraVmaVxvz6EUc',
#   'name': 'Jung Kook',
#   'type': 'artist',
#   'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}]

# %%
data['items'][30]['track']['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#   'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#   'id': '7Ln80lUS6He07XvHI8qqHH',
#   'name': 'Arctic Monkeys',
#   'type': 'artist',
#   'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}]

# %%
#both the for loops below give same output
for i in data['items']:
    album_track = i['track']
    print(album_track)
# Out:
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW
# ...

# %%
for i in data['items']:
    for key,value in i.items():
        if key == 'track':
            print(value)
# Out:
# {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW
# ...

# %%
for i in data['items']:
    for key,value in i.items():
        if key == 'track':
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'}, 'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ', 'id': '3MdXrJWsbVzdn6fe5JYkSQ', 'name': 'Latto', 'type': 'artist', 'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}]
# ...

# %%
for i in data['items']:
    for key,value in i.items():
        if key == 'track':
            print(value['album'])
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', '
# ...

# %%
for i in data['items']:
    for key,value in i.items():
        if key == 'track':
            print(value['album']['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'}, 'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc', 'id': '6HaGTQPmzraVmaVxvz6EUc', 'name': 'Jung Kook', 'type': 'artist', 'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'}, 'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym', 'id': '45dkTj5sMRSjrmBSBeiHym', 'name': 'Tate McRae', 'type': 'artist', 'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'}]
# ...

# %%
artist_list=[]
for i in data['items']:
    for key,value in i.items():
        if key == 'track':
            for j in value['artists']:
                artist_info = {'artist_id': j['id'],'artist_name':j['name']} #and other fields can be pulled the same way
                artist_list.append(artist_info)
print(artist_list)
# Out:
# [{'artist_id': '6HaGTQPmzraVmaVxvz6EUc', 'artist_name': 'Jung Kook'}, {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ', 'artist_name': 'Latto'}, {'artist_id': '6HaGTQPmzraVmaVxvz6EUc', 'artist_name': 'Jung Kook'}, {'artist_id': '45dkTj5sMRSjrmBSBeiHym', 'artist_name': 'Tate McRae'}, {'artist_id': '0jbo7KFNMiIkfBR6ih0yhm', 'artist_name': 'iñigo quintero'}, {'artist_id': '06HL4z0CvFAxyc27GXpf02', 'artist_name': 'Taylor Swift'}, {'artist_id': '5cj0lLjcoR7YOSnhnX0Po5', 'artist_name': 'Doja Cat'}, {'artist_id': '6HaGTQPmzraVmaVxvz6EUc', 'artist_name': 'Jung Kook'}, {'artist_id': '2LIk90788K0zvyj2JJVwkJ', 'artist_name': 'Jack Harlow'}, {'artist_id': '4q3ewBCX7sLwd24euuV69X', 'artist_name': 'Bad Bunny'}, {'artist_id': '2LRoIwlKmHjgvigdNGBHNo', 'artist_name': 'Feid'}, {'artist_id': '06HL4z0CvFAxyc27GXpf02', 'artist_name': 'Taylor Swift'}, {'artist_id': '4q3ewBCX7sLwd24euuV69X', 'artist_name': 'Bad Bunny'}, {'artist_id': '7uMDnSZyUYNBPLhPMNuaM2', 'artist_name': 'Kenya Grace'}, {'artist_id': '06HL4z0CvF
# ...

# %%
#creating df using dict
album_df = pd.DataFrame(album_dict)

# %%
album_df.head()
# Out:
#                  album_id                     name album_release_date  \
# 0  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 1  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 2  3UOV8XvCwMKaATRNXrYCjN                   greedy         2023-09-15
# 3  66k6EGkPtYoN44anGIsEPW              Si No Estás         2022-09-23
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)         2023-10-26
#
#    album_total_tracks
# 0                  11
# 1                  11
# 2                   1
# 3                   1
# 4                  21

# %%
#creating df using list
#when list has multiple dictionaries (all with same keys), then the df can be easily created kyunki keys same hain agar alag bhi
#ho toh jo alag hai wo nan value le leta hai.
album_df1 = pd.DataFrame(album_collated_data)

# %%
album_df1.head()
# Out:
#                  album_id                     name album_release_date  \
# 0  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 1  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 2  3UOV8XvCwMKaATRNXrYCjN                   greedy         2023-09-15
# 3  66k6EGkPtYoN44anGIsEPW              Si No Estás         2022-09-23
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)         2023-10-26
#
#    album_total_tracks
# 0                  11
# 1                  11
# 2                   1
# 3                   1
# 4                  21

# %%
album_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   name                50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %%
album_df1.loc[0:4:2]
# Out:
#                  album_id                     name album_release_date  \
# 0  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 2  3UOV8XvCwMKaATRNXrYCjN                   greedy         2023-09-15
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)         2023-10-26
#
#    album_total_tracks
# 0                  11
# 2                   1
# 4                  21

# %%
album_df1 = album_df1.drop_duplicates(subset=['album_id'],keep='first')

# %%
album_df1.head()
# Out:
#                  album_id                     name album_release_date  \
# 0  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 2  3UOV8XvCwMKaATRNXrYCjN                   greedy         2023-09-15
# 3  66k6EGkPtYoN44anGIsEPW              Si No Estás         2022-09-23
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)         2023-10-26
# 5  1bBez9PNvkJPW08bU7NYta                  Scarlet         2023-09-20
#
#    album_total_tracks
# 0                  11
# 2                   1
# 3                   1
# 4                  21
# 5                  15

# %%
artist_df = pd.DataFrame(artist_list)

# %%
artist_df
# Out:
#                  artist_id         artist_name
# 0   6HaGTQPmzraVmaVxvz6EUc           Jung Kook
# 1   3MdXrJWsbVzdn6fe5JYkSQ               Latto
# 2   6HaGTQPmzraVmaVxvz6EUc           Jung Kook
# 3   45dkTj5sMRSjrmBSBeiHym          Tate McRae
# 4   0jbo7KFNMiIkfBR6ih0yhm      iñigo quintero
# ..                     ...                 ...
# 63  6Sbl0NT50roqWvy746MfVf  Gabito Ballesteros
# 64  0elWFr7TW8piilVRYJUe4P       Natanael Cano
# 65  52iwsT98xCoGgiGntTiR7K             Quevedo
# 66  06HL4z0CvFAxyc27GXpf02        Taylor Swift
# 67  2txHhyCwHjUEpJjWrEyqyX           Tom Odell
#
# [68 rows x 2 columns]

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'],keep='first')

# %%
artist_df
# Out:
#                  artist_id         artist_name
# 0   6HaGTQPmzraVmaVxvz6EUc           Jung Kook
# 1   3MdXrJWsbVzdn6fe5JYkSQ               Latto
# 3   45dkTj5sMRSjrmBSBeiHym          Tate McRae
# 4   0jbo7KFNMiIkfBR6ih0yhm      iñigo quintero
# 5   06HL4z0CvFAxyc27GXpf02        Taylor Swift
# 6   5cj0lLjcoR7YOSnhnX0Po5            Doja Cat
# 8   2LIk90788K0zvyj2JJVwkJ         Jack Harlow
# 9   4q3ewBCX7sLwd24euuV69X           Bad Bunny
# 10  2LRoIwlKmHjgvigdNGBHNo                Feid
# 13  7uMDnSZyUYNBPLhPMNuaM2         Kenya Grace
# 15  2uYWxilOVlUdk4oV9DvwqK              Mitski
# 16  3SozjO3Lat463tQICI9LcE                Tyla
# 17  3WrFJ7ztbogyGnTHbHJFl2         The Beatles
# 21  790FomKkXshlbRYZFtlgla             KAROL G
# 22  12GqGscKJx3aE4t07u7eVZ          Peso Pluma
# 23  0ys2OFYzWYB5hRDLCsBqxt       Fuerza Regida
# 24  64KEffDW9EtZ1y2vBYgq8T          Marshmello
# 26  6dLuQ5qXxIuWc5urxfIiZR            Calle 24
# 27  2rmkQLzj0k4nZdQehOUByO         Chino Pacas
# ...

# %%
songs_list =[]
for i in data['items']:
    song_id = i['track']['id']
    song_name = i['track']['name']
    song_duration = i['track']['duration_ms']
    song_popularity = i['track']['popularity']
    album_id = i['track']['album']['id']
    artist_id = i['track']['album']['artists'][0]['id']
    songs_dict={'song_id': song_id,'song_name':song_name,'song_duration':song_duration,'song_popularity':song_popularity,
                'album_id':album_id, 'artist_id':artist_id}
    songs_list.append(songs_dict)
print(songs_list)
# Out:
# [{'song_id': '2HRgqmZQC0MC7GeNuDIXHN', 'song_name': 'Seven (feat. Latto) (Explicit Ver.)', 'song_duration': 183550, 'song_popularity': 0, 'album_id': '5pSk3c3wVwnb2arb6ohCPU', 'artist_id': '6HaGTQPmzraVmaVxvz6EUc'}, {'song_id': '2KslE17cAJNHTsI2MI0jb2', 'song_name': 'Standing Next to You', 'song_duration': 206019, 'song_popularity': 0, 'album_id': '5pSk3c3wVwnb2arb6ohCPU', 'artist_id': '6HaGTQPmzraVmaVxvz6EUc'}, {'song_id': '3rUGC1vUpkDG9CZFHMur1t', 'song_name': 'greedy', 'song_duration': 131872, 'song_popularity': 99, 'album_id': '3UOV8XvCwMKaATRNXrYCjN', 'artist_id': '45dkTj5sMRSjrmBSBeiHym'}, {'song_id': '2HafqoJbgXdtjwCOvNEF14', 'song_name': 'Si No Estás', 'song_duration': 184061, 'song_popularity': 99, 'album_id': '66k6EGkPtYoN44anGIsEPW', 'artist_id': '0jbo7KFNMiIkfBR6ih0yhm'}, {'song_id': '1Iq8oo9XkmmvCQiGOfORiz', 'song_name': "Is It Over Now? (Taylor's Version) (From The Vault)", 'song_duration': 229477, 'song_popularity': 91, 'album_id': '64LU4c1nfjz1t4VnGhagcg', 'artist_id'
# ...

# %%
songs_df=pd.DataFrame(songs_list)

# %%
songs_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  2HRgqmZQC0MC7GeNuDIXHN                Seven (feat. Latto) (Explicit Ver.)
# 1  2KslE17cAJNHTsI2MI0jb2                               Standing Next to You
# 2  3rUGC1vUpkDG9CZFHMur1t                                             greedy
# 3  2HafqoJbgXdtjwCOvNEF14                                        Si No Estás
# 4  1Iq8oo9XkmmvCQiGOfORiz  Is It Over Now? (Taylor's Version) (From The V...
#
#    song_duration  song_popularity                album_id  \
# 0         183550                0  5pSk3c3wVwnb2arb6ohCPU
# 1         206019                0  5pSk3c3wVwnb2arb6ohCPU
# 2         131872               99  3UOV8XvCwMKaATRNXrYCjN
# 3         184061               99  66k6EGkPtYoN44anGIsEPW
# 4         229477               91  64LU4c1nfjz1t4VnGhagcg
#
#                 artist_id
# 0  6HaGTQPmzraVmaVxvz6EUc
# 1  6HaGTQPmzraVmaVxvz6EUc
# 2  45dkTj5sMRSjrmBSBeiHym
# 3  0jbo7KFNMiIkfBR6ih0yhm
# ...

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name
# 0  6HaGTQPmzraVmaVxvz6EUc       Jung Kook
# 1  3MdXrJWsbVzdn6fe5JYkSQ           Latto
# 3  45dkTj5sMRSjrmBSBeiHym      Tate McRae
# 4  0jbo7KFNMiIkfBR6ih0yhm  iñigo quintero
# 5  06HL4z0CvFAxyc27GXpf02    Taylor Swift

# %%
album_df1.head()
# Out:
#                  album_id                     name album_release_date  \
# 0  5pSk3c3wVwnb2arb6ohCPU                   GOLDEN         2023-11-03
# 2  3UOV8XvCwMKaATRNXrYCjN                   greedy         2023-09-15
# 3  66k6EGkPtYoN44anGIsEPW              Si No Estás         2022-09-23
# 4  64LU4c1nfjz1t4VnGhagcg  1989 (Taylor's Version)         2023-10-26
# 5  1bBez9PNvkJPW08bU7NYta                  Scarlet         2023-09-20
#
#    album_total_tracks
# 0                  11
# 2                   1
# 3                   1
# 4                  21
# 5                  15

# %%
album_df1['album_release_date'] = pd.to_datetime(album_df1['album_release_date'])

# %%
album_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            34 non-null     object
#  1   name                34 non-null     object
#  2   album_release_date  34 non-null     datetime64[ns]
#  3   album_total_tracks  34 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 1.3+ KB

# %%
#now we have dfs well transformed. We can do anything with that. We can apply joins too.
